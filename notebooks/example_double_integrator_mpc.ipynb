# %%
# ── Repo-root bootstrap (added for folder reorg) ──────────────────────────────
# Make ../controllers and ../python importable and locate ../data, regardless of
# whether this notebook is launched from notebooks/ or the repository root.
import sys, os
ROOT = os.getcwd()
for _ in range(4):
    if os.path.isdir(os.path.join(ROOT, "controllers")):
        break
    ROOT = os.path.dirname(ROOT)
for _sub in ("controllers", "python"):
    _p = os.path.join(ROOT, _sub)
    if _p not in sys.path:
        sys.path.insert(0, _p)
DATA = os.path.join(ROOT, "data")

# %% [markdown]
# # Example 01 — MPC with Certificate-based Terminal Set
#
# **System**: Double integrator $\dot{x}_1 = x_2,\; \dot{x}_2 = u$
#
# **Goal**: Drive the output $y = x_1$ into the target set $\mathcal{X}^r = \{x : x_1^2 \le 0.01\}$ while remaining in the safe set $\mathcal{X}_S = \{x : x_1^2 \le 1\}$.
#
# **MPC Terminal Set**: The zero super-level set of the reach-avoid certificate `certificate_opt`, i.e., $\{x : V(x) \ge 0\}$.
# This guarantees that once the MPC drives the state into the certified region, the certificate-based controller can complete the reach-avoid task, providing a composable safety and convergence guarantee.

# %%
# ── Imports & load computed certificate / controller ─────────────────────────
import sympy as sp
import numpy as np
import casadi as ca
import matplotlib.pyplot as plt
from functional import BetterColor

from sop_bounded_control_ex1_debug_20260314_213424 import (
    u_opt as u_opt_list,
    certificate_opt,
)

x1_sym, x2_sym = sp.symbols("x1 x2")
y1_sym = sp.symbols("y1", real=True)

u_opt_sym = sp.Matrix(u_opt_list)

print("Certificate V(x1, x2):")
print(certificate_opt)
print("\nNo-MPC controller u(x1, x2):")
print(u_opt_sym[0])
print(f"\nCasADi version: {ca.__version__}")
# Out:
# Certificate V(x1, x2):
# -x1**2 - (-0.024408*x1**4 + 0.50236*x1**3 - 0.17979*x1**2 + 1.2929*x1 + x2 + 0.0039964)**2/20 + 1
#
# No-MPC controller u(x1, x2):
# -9.27542283912569e-5*x1**4 + 0.00190904679509308*x1**3 - 0.000683230200035401*x1**2 - 19.9950867772088*x1 + x2*(0.097632*x1**3 - 1.50708*x1**2 + 0.35958*x1 - 1.2929) + 8762565106153311*x2/2305843009213693952 + 1.51869468347599e-5
#
# CasADi version: 3.7.0

# %%
# ── System & set definitions ─────────────────────────────────────────────────
f_sym = sp.Matrix([x2_sym, 0])
g_sym = sp.Matrix([[0], [1]])
hx_sym = sp.Matrix([x1_sym])  # output map

safe_set_sym = 1 - y1_sym**2  # psi(y) >= 0  inside safe set
target_set_sym = y1_sym**2 - 0.01  # phi(y) <= 0  inside target set

# Substitute output map to get set expressions in x-coordinates
safe_set_x_sym = safe_set_sym.subs({y1_sym: hx_sym[0]})
target_set_x_sym = target_set_sym.subs({y1_sym: hx_sym[0]})

certificate_func = sp.lambdify([x1_sym, x2_sym], certificate_opt, "numpy")
target_set_x_func = sp.lambdify([x1_sym, x2_sym], target_set_x_sym, "numpy")
safe_set_x_func = sp.lambdify([x1_sym, x2_sym], safe_set_x_sym, "numpy")
u_nompc_func = sp.lambdify([x1_sym, x2_sym], u_opt_sym[0], "numpy")

print("Safe set  (x):  ", safe_set_x_sym, ">= 0")
print("Target set (x): ", target_set_x_sym, "<= 0")
# Out:
# Safe set  (x):   1 - x1**2 >= 0
# Target set (x):  x1**2 - 0.01 <= 0

# %%
# ── Sample valid initial states (outside certificate superlevel set, inside safe set) ──
N_samples = 10000
np.random.seed(4)

lower_bound = np.array([-1.0, -10.0])
upper_bound = np.array([1.0, 10.0])
x_samples = np.random.random((2, N_samples)) * (upper_bound - lower_bound).reshape(
    -1, 1
) + lower_bound.reshape(-1, 1)

cert_vals = certificate_func(x_samples[0], x_samples[1])
safe_set_vals = safe_set_x_func(x_samples[0], x_samples[1])

valid_idx = np.where((cert_vals < 0) & (safe_set_vals >= 0))[0]
x_samples_valid = x_samples[:, valid_idx]

print(f"Total valid samples: {valid_idx.shape[0]},  using: {x_samples_valid.shape[1]}")
# Out:
# Total valid samples: 6527,  using: 6527

# %%
# ── Sympy → CasADi symbolic expression converter ────────────────────────────
def sympy2casadi(expr, sym_map):
    """Recursively convert a sympy expression to a CasADi expression."""
    if isinstance(
        expr,
        (
            sp.Integer,
            sp.Float,
            sp.Rational,
            sp.core.numbers.NegativeOne,
            sp.core.numbers.Half,
            sp.core.numbers.One,
            sp.core.numbers.Zero,
        ),
    ):
        return float(expr)
    elif isinstance(expr, sp.Symbol):
        return sym_map[expr]
    elif isinstance(expr, sp.Add):
        return sum(sympy2casadi(a, sym_map) for a in expr.args)
    elif isinstance(expr, sp.Mul):
        result = 1.0
        for a in expr.args:
            result = result * sympy2casadi(a, sym_map)
        return result
    elif isinstance(expr, sp.Pow):
        base = sympy2casadi(expr.args[0], sym_map)
        exp = sympy2casadi(expr.args[1], sym_map)
        return base**exp
    elif isinstance(expr, sp.Number):  # catch-all for other numeric types
        return float(expr)
    else:
        raise ValueError(f"Unsupported sympy type: {type(expr)}  —  {expr}")


# Shared CasADi symbols for conversion
ca_x1_s = ca.SX.sym("x1")
ca_x2_s = ca.SX.sym("x2")

# CasADi function for the reach-avoid certificate V(x1, x2)
cert_ca_expr = sympy2casadi(certificate_opt, {x1_sym: ca_x1_s, x2_sym: ca_x2_s})
cert_ca_func = ca.Function("cert", [ca_x1_s, ca_x2_s], [cert_ca_expr])

# CasADi function for the safe set: psi(x1, x2) = 1 - x1^2 >= 0
safe_set_ca_expr = sympy2casadi(safe_set_x_sym, {x1_sym: ca_x1_s, x2_sym: ca_x2_s})
safe_set_ca_func = ca.Function("safe_set", [ca_x1_s, ca_x2_s], [safe_set_ca_expr])

# Sanity checks
test = np.array([0.3, 1.5])
v_sp = float(certificate_opt.subs({x1_sym: test[0], x2_sym: test[1]}))
v_ca = float(cert_ca_func(test[0], test[1]))
print(f"Certificate at {test}:  sympy = {v_sp:.8f},  casadi = {v_ca:.8f}")
assert abs(v_sp - v_ca) < 1e-8, "Certificate conversion mismatch!"

s_sp = float(safe_set_x_sym.subs({x1_sym: test[0], x2_sym: test[1]}))
s_ca = float(safe_set_ca_func(test[0], test[1]))
print(f"Safe set  at {test}:  sympy = {s_sp:.8f},  casadi = {s_ca:.8f}")
assert abs(s_sp - s_ca) < 1e-8, "Safe set conversion mismatch!"

print("All conversions verified OK.")
# Out:
# Certificate at [0.3 1.5]:  sympy = 0.73157426,  casadi = 0.73157426
# Safe set  at [0.3 1.5]:  sympy = 0.91000000,  casadi = 0.91000000
# All conversions verified OK.

# %%
# ── MPC problem formulation ──────────────────────────────────────────────────
# ── Parameters ───────────────────────────────────────────────────────────────
nx = 2  # state dim:   [x1, x2]
nu = 1  # control dim: [u]
dt = 0.01  # MPC discretisation step (s)
N = 20  # prediction horizon (steps → 0.2 s look-ahead)
u_max = 20.0  # control bound  |u| <= u_max

# Cost weights
Q_cost = np.diag([10, 1])  # stage state cost  x_k^T Q x_k
Qf_cost = np.diag([1, 1])  # terminal state cost  x_N^T Qf x_N
R_cost = np.array([[0.01]])  # control magnitude penalty  u_k^T R u_k

# ── CasADi symbolic system ───────────────────────────────────────────────────
x_ca = ca.SX.sym("x", nx)
u_ca = ca.SX.sym("u", nu)

xdot = ca.vertcat(x_ca[1], u_ca[0])  # dx1/dt = x2,  dx2/dt = u
f_ca = ca.Function("f", [x_ca, u_ca], [xdot])

# RK4 integrator (one step of length dt)
k1 = f_ca(x_ca, u_ca)
k2 = f_ca(x_ca + dt / 2 * k1, u_ca)
k3 = f_ca(x_ca + dt / 2 * k2, u_ca)
k4 = f_ca(x_ca + dt * k3, u_ca)
x_next_expr = x_ca + dt / 6 * (k1 + 2 * k2 + 2 * k3 + k4)
F_ca = ca.Function("F", [x_ca, u_ca], [x_next_expr])

# ── Opti NLP ─────────────────────────────────────────────────────────────────
opti = ca.Opti()

X_var = opti.variable(nx, N + 1)  # state trajectory
U_var = opti.variable(nu, N)  # control sequence
x0_param = opti.parameter(nx)  # current state (set at run-time)

# ── Cost: stage state + stage control + terminal state ────────────────────────
cost = 0

for k in range(N):
    cost += X_var[:, k].T @ Q_cost @ X_var[:, k]  # stage state cost
    cost += U_var[:, k].T @ R_cost @ U_var[:, k]  # control magnitude cost

cost += X_var[:, N].T @ Qf_cost @ X_var[:, N]  # terminal state cost

opti.minimize(cost)

# ── Constraints ──────────────────────────────────────────────────────────────
opti.subject_to(X_var[:, 0] == x0_param)  # initial condition
for k in range(N):
    opti.subject_to(X_var[:, k + 1] == F_ca(X_var[:, k], U_var[:, k]))  # dynamics

opti.subject_to(opti.bounded(-u_max, U_var[0, :], u_max))  # control bounds

# Safe set constraint: psi(x_k) >= 0 for all k in horizon
for k in range(N + 1):
    opti.subject_to(safe_set_ca_func(X_var[0, k], X_var[1, k]) >= 0)

# ── Terminal set: certificate_opt(x_N) >= 0 ──────────────────────────────────
terminal_cert = cert_ca_func(X_var[0, N], X_var[1, N])
opti.subject_to(terminal_cert >= 0)

# ── Solver ────────────────────────────────────────────────────────────────────
opts = {"ipopt.print_level": 0, "print_time": False, "ipopt.max_iter": 600}
opti.solver("ipopt", opts)

print("MPC NLP built successfully.")
print(f"  nx={nx}, nu={nu}, N={N}, dt={dt} s  (horizon = {N * dt:.2f} s)")
print(f"  Control bound:  |u| <= {u_max}")
print(f"  Stage cost:     x_k^T Q x_k   (Q  = diag{np.diag(Q_cost).tolist()})")
print(f"  Terminal cost:  x_N^T Qf x_N  (Qf = diag{np.diag(Qf_cost).tolist()})")
print(f"  Control cost:   u_k^T R u_k   (R  = {float(R_cost[0, 0])})")
print(f"  Terminal set:   V(x_N) >= 0   (zero super-level set of certificate_opt)")
# Out:
# MPC NLP built successfully.
#   nx=2, nu=1, N=20, dt=0.01 s  (horizon = 0.20 s)
#   Control bound:  |u| <= 20.0
#   Stage cost:     x_k^T Q x_k   (Q  = diag[10, 1])
#   Terminal cost:  x_N^T Qf x_N  (Qf = diag[1, 1])
#   Control cost:   u_k^T R u_k   (R  = 0.01)
#   Terminal set:   V(x_N) >= 0   (zero super-level set of certificate_opt)

# %%
# select samples that feasible for the first step MPC optimization
feasible_idx = []
max_feasible_samples = 100  # max samples to check for MPC feasibility

for i in range(x_samples_valid.shape[1]):

    x0 = x_samples_valid[:, i].copy()

    if float(target_set_x_func(x0[0], x0[1])) <= 0:
        print(f"Sample {i}: already in target set — skipped")
        continue

    # print(f"Simulating sample {i}  (x0 = {x0.round(4)}) ...", end=" ")

    x_cur = x0.copy()
    this_traj_x = [x_cur.copy()]
    this_traj_u = []
    failed = False

    # one step MPC simulation loop
    opti.set_value(x0_param, x_cur)

    try:
        sol = opti.solve()
        u_mpc = sol.value(U_var[:, 0])
        X_pred = sol.value(X_var)
        U_pred = sol.value(U_var)
        print(f"  MPC feasible for sample {i}  (x0 = {x0.round(4)}) ...", end=" ")
    except Exception as e:
        # print(f"\n  [1st step solver failed: {e} — skipping this trajectory")
        failed = True
        continue

    # else save this sample for later simulation and visualization
    feasible_idx.append(i)
    if len(feasible_idx) >= max_feasible_samples:
        print(
            f"\nReached max feasible samples limit ({max_feasible_samples}) — stopping MPC feasibility checks."
        )
        break


# Filter valid samples based on first-step MPC feasibility and target set membership
x_samples_valid = x_samples_valid[:, feasible_idx]
print(f"\nTotal feasible samples after MPC feasibility check: {len(feasible_idx)}")
# Out:
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# Sample 1: already in target set — skipped
#   MPC feasible for sample 2  (x0 = [0.9454 0.2623]) ...   MPC feasible for sample 6  (x0 = [-0.494  5.922]) ...   MPC feasible for sample 8  (x0 = [-0.6046  5.1169]) ...   MPC feasible for sample 11  (x0 = [-0.982   6.7264]) ...   MPC feasible for sample 13  (x0 = [-0.9117  3.6648]) ...   MPC feasible for sample 18  (x0 = [-0.8501  4.0319]) ... Sample 22: already in target set — skipped
# Sample 23: already in target set — skipped
# Sample 24: already in target set — skipped
# Sample 29: already in target set — skipped
# Sample 36: already in target set — skipped
#   MPC feasible for sample 38  (x0 = [0.8368 1.2237]) ...   MPC feasible for sample 42  (x0 = [-0.3377  5.7466]) ...   MPC feasible for sample 43  (x0 = [0.722  2.1265]) ... Sample 48: already in target set — skipped
#   MPC feasible for sample 56  (x0 = [ 0.6874 -6.0644]) ...   MPC feasible for sample 63  (x0 = [-0.6219 -3.0832]) ... Sample 64: already in target set — skipped
#   MPC feasible for sample 67  (x0 = [-0.4782 -3.3611]) ...   MPC feasible for sample 74  (x0 = [ 0.652  -6.8435]) ...   MPC feasible for sample 82  (x0 = [ 0.5056 -6.7798]) ...   MPC feasible for sample 83  (x0 = [ 0.9624 -6.6917]) ... Sample 89: already in target set — skipped
#   MPC feasible for sample 91  (x0 = [ 0.8993 -5.2621]) ...   MPC feasible for sample 98  (x0 = [0.1039 4.4913]) ...   MPC feasible for sample 100  (x0 = [ 0.9816 -6.8802]) ...   MPC feasible for sample 101  (x0 = [-0.8527 -2.0736]) ...   MPC feasible for sample 102  (x0 = [-0.7305 -2.5271]) ...   MPC feasible for sample 103  (x0 = [ 0.4801 -5.7944]) ...   MPC feasible for sample 104  (x0 = [ 0.6676 -5.7093]) ...   MPC feasible for sample 105  (x0 = [-0.8225  7.36  ]) ...   MPC feasible for sample 106  (x0 = [0.6588 3.2072]) ...   MPC feasible for sample 109  (x0 = [-0.2673  5.1165]) ...   MPC feasible for sample 111  (x0 = [ 0.8706 -6.4958]) ...   MPC feasible for sample 119  (x0 = [ 0.2737 -5.4409]) ...   MPC feasible for sample 122  (x0 = [-0.335  5.313]) ...   MPC feasible for sample 126  (x0 = [-0.9405 -1.4362]) ...   MPC feasible for sample 128  (x0 = [0.2236 5.0533]) ...   MPC feasible for sample 129  (x0 = [0.8668 1.189 ]) ...   MPC feasible for sample 130  (x0 = [ 0.469  -5.1423]) ...   MPC feasible for sample 131  (x0 = [ 0.8149 -6.5356]) ...   MPC feasible for sample 132  (x0 = [-0.6296  4.9929]) ...   MPC feasible for sample 133  (x0 = [ 0.7213 -7.4042]) ...   MPC feasible for sample 135  (x0 = [-0.8951  5.8023]) ... Sample 138: already in target set — skipped
#   MPC feasible for sample 141  (x0 = [ 0.8967 -6.3745]) ...   MPC feasible for sample 142  (x0 = [ 0.9084 -7.3541]) ... Sample 144: already in target set — skipped
#   MPC feasible for sample 149  (x0 = [-0.4411  5.7635]) ...   MPC feasible for sample 150  (x0 = [-0.5363  6.7789]) ...   MPC feasible for sample 157  (x0 = [-0.8346 -1.2442]) ...   MPC feasible for sample 158  (x0 = [ 0.9724 -3.9882]) ...   MPC feasible for sample 160  (x0 = [ 0.1686 -5.5243]) ...   MPC feasible for sample 162  (x0 = [ 0.7774 -6.5255]) ...   MPC feasible for sample 163  (x0 = [-0.6645  6.2846]) ...   MPC feasible for sample 170  (x0 = [ 0.6841 -5.8484]) ...   MPC feasible for sample 176  (x0 = [ 0.7536 -7.1375]) ...   MPC feasible for sample 180  (x0 = [0.2777 4.1474]) ... Sample 181: already in target set — skipped
#   MPC feasible for sample 183  (x0 = [-0.7536  6.9865]) ...   MPC feasible for sample 186  (x0 = [ 0.46   -5.3419]) ... Sample 187: already in target set — skipped
# Sample 193: already in target set — skipped
#   MPC feasible for sample 196  (x0 = [-0.4538  5.3681]) ... Sample 203: already in target set — skipped
#   MPC feasible for sample 204  (x0 = [-0.9458  7.3084]) ... Sample 208: already in target set — skipped
#   MPC feasible for sample 211  (x0 = [ 0.6965 -5.9404]) ...   MPC feasible for sample 214  (x0 = [ 0.8173 -6.6242]) ...   MPC feasible for sample 219  (x0 = [-0.8445  6.3356]) ...   MPC feasible for sample 221  (x0 = [ 0.4063 -5.5692]) ...   MPC feasible for sample 222  (x0 = [-0.8767  6.2302]) ... Sample 223: already in target set — skipped
# Sample 224: already in target set — skipped
#   MPC feasible for sample 225  (x0 = [0.965  0.6142]) ...   MPC feasible for sample 226  (x0 = [-0.9571  5.4334]) ... Sample 227: already in target set — skipped
#   MPC feasible for sample 228  (x0 = [0.2503 4.7789]) ... Sample 230: already in target set — skipped
#   MPC feasible for sample 231  (x0 = [ 0.1452 -5.014 ]) ... Sample 232: already in target set — skipped
#   MPC feasible for sample 237  (x0 = [ 0.5638 -5.9083]) ...   MPC feasible for sample 238  (x0 = [0.7448 2.6048]) ...   MPC feasible for sample 239  (x0 = [-0.3472  5.2828]) ...   MPC feasible for sample 240  (x0 = [-0.4223  5.9994]) ...   MPC feasible for sample 241  (x0 = [-0.8366 -1.4988]) ... Sample 245: already in target set — skipped
#   MPC feasible for sample 246  (x0 = [0.3867 3.7973]) ...   MPC feasible for sample 253  (x0 = [-0.7567  7.4439]) ... Sample 254: already in target set — skipped
#   MPC feasible for sample 257  (x0 = [0.4016 4.3616]) ...   MPC feasible for sample 259  (x0 = [-0.7581  4.2438]) ... Sample 260: already in target set — skipped
#   MPC feasible for sample 264  (x0 = [-0.6615 -2.8211]) ... Sample 266: already in target set — skipped
#   MPC feasible for sample 272  (x0 = [-0.3128  6.2943]) ... Sample 273: already in target set — skipped
#   MPC feasible for sample 275  (x0 = [0.5148 3.6782]) ...   MPC feasible for sample 277  (x0 = [ 0.7749 -5.7984]) ...   MPC feasible for sample 278  (x0 = [-0.4033  5.5459]) ...   MPC feasible for sample 282  (x0 = [-0.3994  4.8409]) ... Sample 283: already in target set — skipped
# Sample 285: already in target set — skipped
# Sample 287: already in target set — skipped
#   MPC feasible for sample 290  (x0 = [ 0.7709 -6.7528]) ... Sample 291: already in target set — skipped
#   MPC feasible for sample 292  (x0 = [-0.6132  5.4936]) ...   MPC feasible for sample 295  (x0 = [ 0.2412 -4.8783]) ...   MPC feasible for sample 297  (x0 = [-0.6893  7.4968]) ...   MPC feasible for sample 299  (x0 = [-0.3374  6.5565]) ...   MPC feasible for sample 303  (x0 = [-0.6209  7.0583]) ... Sample 306: already in target set — skipped
#   MPC feasible for sample 308  (x0 = [ 0.2777 -4.6608]) ...   MPC feasible for sample 310  (x0 = [-0.9193  3.7668]) ...   MPC feasible for sample 311  (x0 = [-0.8702  5.0402]) ... Sample 316: already in target set — skipped
#   MPC feasible for sample 317  (x0 = [-0.9629  0.3169]) ...   MPC feasible for sample 325  (x0 = [ 0.6885 -6.4814]) ...   MPC feasible for sample 326  (x0 = [0.8298 2.2807]) ...   MPC feasible for sample 328  (x0 = [-0.9204  4.6786]) ...   MPC feasible for sample 330  (x0 = [-0.9982  1.5812]) ...   MPC feasible for sample 332  (x0 = [ 0.9987 -7.8668]) ...   MPC feasible for sample 335  (x0 = [-0.7277 -3.0118]) ...   MPC feasible for sample 337  (x0 = [ 0.4446 -6.057 ]) ...   MPC feasible for sample 343  (x0 = [-0.7729  5.6797]) ... Sample 347: already in target set — skipped
#   MPC feasible for sample 348  (x0 = [0.9513 1.1436]) ...   MPC feasible for sample 355  (x0 = [ 0.126  -5.8195]) ...   MPC feasible for sample 358  (x0 = [-0.8708  6.1012]) ...   MPC feasible for sample 359  (x0 = [-0.9196 -0.2368]) ...   MPC feasible for sample 360  (x0 = [-0.2489  5.4057]) ...   MPC feasible for sample 363  (x0 = [-0.2224  5.2278]) ...
# Reached max feasible samples limit (100) — stopping MPC feasibility checks.
#
# Total feasible samples after MPC feasibility check: 100

# %%
# ── Closed-loop MPC simulation ───────────────────────────────────────────────
max_steps_per_traj = 2000  # max MPC steps per trajectory

traj_x_mpc = []
traj_u_mpc = []

max_trajs = 50  # max trajectories to visualization

for i in range(x_samples_valid.shape[1]):
    if max_trajs <= 0:
        break

    x0 = x_samples_valid[:, i].copy()

    if float(target_set_x_func(x0[0], x0[1])) <= 0:
        print(f"Sample {i}: already in target set — skipped")
        traj_x_mpc.append(x0.reshape(1, -1))
        traj_u_mpc.append(np.array([]))
        continue

    print(f"Simulating sample {i}  (x0 = {x0.round(4)}) ...", end=" ")

    x_cur = x0.copy()
    this_traj_x = [x_cur.copy()]
    this_traj_u = []
    failed = False

    for step in range(max_steps_per_traj):
        opti.set_value(x0_param, x_cur)

        try:
            sol = opti.solve()
            u_mpc = sol.value(U_var[:, 0])
            X_pred = sol.value(X_var)
            U_pred = sol.value(U_var)
        except Exception as e:
            print(f"\n  [step {step}] solver failed: {e} — skipping this trajectory")
            failed = True
            break

        # Apply first control action (one RK4 step)
        x_next = np.array(
            F_ca(x_cur, [u_mpc] if np.isscalar(u_mpc) else u_mpc)
        ).flatten()
        this_traj_x.append(x_next.copy())
        this_traj_u.append(float(u_mpc) if np.isscalar(u_mpc) else float(u_mpc[0]))
        x_cur = x_next

        if float(target_set_x_func(x_cur[0], x_cur[1])) <= 0:
            print(f"reached target at step {step + 1}  (t = {(step + 1) * dt:.2f} s)")
            break
    else:
        print(f"max steps reached")

    if not failed:
        traj_x_mpc.append(np.array(this_traj_x))
        traj_u_mpc.append(np.array(this_traj_u))
        max_trajs -= 1

print(f"\nAll done. {len(traj_x_mpc)} trajectories simulated.")
# Out:
# Simulating sample 0  (x0 = [0.9454 0.2623]) ... reached target at step 209  (t = 2.09 s)
# Simulating sample 1  (x0 = [-0.494  5.922]) ... reached target at step 8  (t = 0.08 s)
# Simulating sample 2  (x0 = [-0.6046  5.1169]) ... reached target at step 14  (t = 0.14 s)
# Simulating sample 3  (x0 = [-0.982   6.7264]) ... reached target at step 18  (t = 0.18 s)
# Simulating sample 4  (x0 = [-0.9117  3.6648]) ... reached target at step 150  (t = 1.50 s)
# Simulating sample 5  (x0 = [-0.8501  4.0319]) ... reached target at step 123  (t = 1.23 s)
# Simulating sample 6  (x0 = [0.8368 1.2237]) ... reached target at step 209  (t = 2.09 s)
# Simulating sample 7  (x0 = [-0.3377  5.7466]) ... reached target at step 5  (t = 0.05 s)
# Simulating sample 8  (x0 = [0.722  2.1265]) ... reached target at step 210  (t = 2.10 s)
# Simulating sample 9  (x0 = [ 0.6874 -6.0644]) ... reached target at step 13  (t = 0.13 s)
# Simulating sample 10  (x0 = [-0.6219 -3.0832]) ... reached target at step 217  (t = 2.17 s)
# Simulating sample 11  (x0 = [-0.4782 -3.3611]) ... reached target at step 209  (t = 2.09 s)
# Simulating sample 12  (x0 = [ 0.652  -6.8435]) ... reached target at step 10  (t = 0.10 s)
# Simulating sample 13  (x0 = [ 0.5056 -6.7798]) ... reached target at step 7  (t = 0.07 s)
# Simulating sample 14  (x0 = [ 0.9624 -6.6917]) ... reached target at step 18  (t = 0.18 s)
# Simulating sample 15  (x0 = [ 0.8993 -5.2621]) ... reached target at step 40  (t = 0.40 s)
# Simulating sample 16  (x0 = [0.1039 4.4913]) ... reached target at step 197  (t = 1.97 s)
# Simulating sample 17  (x0 = [ 0.9816 -6.8802]) ... reached target at step 18  (t = 0.18 s)
# Simulating sample 18  (x0 = [-0.8527 -2.0736]) ... reached target at step 220  (t = 2.20 s)
# Simulating sample 19  (x0 = [-0.7305 -2.5271]) ... reached target at step 217  (t = 2.17 s)
# Simulating sample 20  (x0 = [ 0.4801 -5.7944]) ... reached target at step 8  (t = 0.08 s)
# Simulating sample 21  (x0 = [ 0.6676 -5.7093]) ... reached target at step 13  (t = 0.13 s)
# Simulating sample 22  (x0 = [-0.8225  7.36  ]) ... reached target at step 12  (t = 0.12 s)
# Simulating sample 23  (x0 = [0.6588 3.2072]) ... reached target at step 222  (t = 2.22 s)
# Simulating sample 24  (x0 = [-0.2673  5.1165]) ... reached target at step 4  (t = 0.04 s)
# Simulating sample 25  (x0 = [ 0.8706 -6.4958]) ... reached target at step 16  (t = 0.16 s)
# Simulating sample 26  (x0 = [ 0.2737 -5.4409]) ... reached target at step 4  (t = 0.04 s)
# Simulating sample 27  (x0 = [-0.335  5.313]) ... reached target at step 5  (t = 0.05 s)
# Simulating sample 28  (x0 = [-0.9405 -1.4362]) ... reached target at step 219  (t = 2.19 s)
# Simulating sample 29  (x0 = [0.2236 5.0533]) ... reached target at step 227  (t = 2.27 s)
# Simulating sample 30  (x0 = [0.8668 1.189 ]) ... reached target at step 211  (t = 2.11 s)
# Simulating sample 31  (x0 = [ 0.469  -5.1423]) ... reached target at step 9  (t = 0.09 s)
# Simulating sample 32  (x0 = [ 0.8149 -6.5356]) ... reached target at step 14  (t = 0.14 s)
# Simulating sample 33  (x0 = [-0.6296  4.9929]) ... reached target at step 16  (t = 0.16 s)
# Simulating sample 34  (x0 = [ 0.7213 -7.4042]) ... reached target at step 10  (t = 0.10 s)
# Simulating sample 35  (x0 = [-0.8951  5.8023]) ... reached target at step 23  (t = 0.23 s)
# Simulating sample 36  (x0 = [ 0.8967 -6.3745]) ... reached target at step 18  (t = 0.18 s)
# Simulating sample 37  (x0 = [ 0.9084 -7.3541]) ... reached target at step 14  (t = 0.14 s)
# Simulating sample 38  (x0 = [-0.4411  5.7635]) ... reached target at step 7  (t = 0.07 s)
# Simulating sample 39  (x0 = [-0.5363  6.7789]) ... reached target at step 8  (t = 0.08 s)
# Simulating sample 40  (x0 = [-0.8346 -1.2442]) ... reached target at step 209  (t = 2.09 s)
# Simulating sample 41  (x0 = [ 0.9724 -3.9882]) ... reached target at step 151  (t = 1.51 s)
# Simulating sample 42  (x0 = [ 0.1686 -5.5243]) ... reached target at step 2  (t = 0.02 s)
# Simulating sample 43  (x0 = [ 0.7774 -6.5255]) ... reached target at step 13  (t = 0.13 s)
# Simulating sample 44  (x0 = [-0.6645  6.2846]) ... reached target at step 11  (t = 0.11 s)
# Simulating sample 45  (x0 = [ 0.6841 -5.8484]) ... reached target at step 13  (t = 0.13 s)
# Simulating sample 46  (x0 = [ 0.7536 -7.1375]) ... reached target at step 11  (t = 0.11 s)
# Simulating sample 47  (x0 = [0.2777 4.1474]) ... reached target at step 207  (t = 2.07 s)
# Simulating sample 48  (x0 = [-0.7536  6.9865]) ... reached target at step 12  (t = 0.12 s)
# Simulating sample 49  (x0 = [ 0.46   -5.3419]) ... reached target at step 8  (t = 0.08 s)
#
# All done. 50 trajectories simulated.

# %%
# filter out too short trajectories & stop at max_steps_per_traj
min_steps = 100
traj_x_mpc = [
    traj
    for traj in traj_x_mpc
    if (traj.shape[0] > min_steps) & (traj.shape[0] < max_steps_per_traj)
]  # keep only trajectories with more than 100 steps (1 second)
traj_u_mpc = [
    traj
    for traj in traj_u_mpc
    if (traj.shape[0] > min_steps) & (traj.shape[0] < max_steps_per_traj)
]  # keep only trajectories with non-empty control sequences

# %%
# ── Phase portrait: safe set / target set / certificate / trajectories ───────
px = 1 / plt.rcParams["figure.dpi"]
fig, ax = plt.subplots(figsize=(650 * px, 600 * px), layout="constrained")
fig.set_dpi(200)

# Evaluation grid
nx1_grid = np.linspace(-1.1, 1.1, 1000)
nx2_grid = np.linspace(-8.0, 8.0, 1000)
X1g, X2g = np.meshgrid(nx1_grid, nx2_grid)

psi_fx = sp.lambdify([x1_sym, x2_sym], safe_set_x_sym, "numpy")
phi_fx = sp.lambdify([x1_sym, x2_sym], target_set_x_sym, "numpy")
Z_psi = psi_fx(X1g, X2g)
Z_phi = phi_fx(X1g, X2g)
Z_cert = certificate_func(X1g, X2g)

# ── Closed-loop vector field (background) ────────────────────────────────────
vf_x1 = np.linspace(-1.1, 1.1, 28)
vf_x2 = np.linspace(-8.0, 8.0, 28)
VF_X1, VF_X2 = np.meshgrid(vf_x1, vf_x2)

closed_loop_sym = f_sym + g_sym @ u_opt_sym
dyn_cl_f = sp.lambdify([x1_sym, x2_sym], closed_loop_sym, "numpy")
VF_dyn = np.array(dyn_cl_f(VF_X1, VF_X2)).squeeze()
ax.streamplot(
    vf_x1,
    vf_x2,
    VF_dyn[0],
    VF_dyn[1],
    density=0.8,
    color=BetterColor.gray0(0.5),
    linewidth=0.8,
    arrowsize=0.8,
    zorder=0,
)

# ── Safe set  (cool blue) ─────────────────────────────────────────────────────
ax.contourf(
    X1g, X2g, Z_psi, levels=[0, np.inf], colors=["#e6f2ff"], alpha=0.3, zorder=1
)
ax.contour(X1g, X2g, Z_psi, levels=[0], colors=["#2166ac"], linewidths=2, zorder=2)

# ── Target set  (warm red) ────────────────────────────────────────────────────
ax.contourf(
    X1g, X2g, Z_phi, levels=[-np.inf, 0], colors=["#fee0d2"], alpha=1, zorder=100
)
ax.contour(X1g, X2g, Z_phi, levels=[0], colors=["#b2182b"], linewidths=4, zorder=101)

# ── Certificate superlevel set  (soft purple) ─────────────────────────────────
ax.contourf(
    X1g, X2g, Z_cert, levels=[0, np.inf], colors=["#ede0f5"], alpha=0.6, zorder=50
)
ax.contour(X1g, X2g, Z_cert, levels=[0], colors=["#7b2d8b"], linewidths=2, zorder=51)

# ── MPC trajectories ─────────────────────────────────────────────────────────
for this_traj in traj_x_mpc:
    if this_traj.shape[0] < 2:
        continue
    ax.plot(
        this_traj[:, 0],
        this_traj[:, 1],
        color="black",
        linestyle="--",
        linewidth=1.5,
        alpha=0.7,
        zorder=200,
    )
    ax.scatter(
        this_traj[0, 0],
        this_traj[0, 1],
        s=50,
        c=BetterColor.orange3(),
        marker="o",
        linewidths=0.3,
        zorder=300,
    )
    ax.scatter(
        this_traj[-1, 0],
        this_traj[-1, 1],
        s=50,
        c=BetterColor.green0(),
        marker="x",
        linewidths=2,
        zorder=300,
    )

this_fontsize = 30
ax.text(0.55, -6.5, r"$\mathcal{X}_S$", zorder=1000, fontsize=this_fontsize)
ax.text(-0.09, 0.5, r"$\mathcal{X}_T$", zorder=1000, fontsize=this_fontsize)
ax.text(-0.55, -2.5, r"$\mathcal{X}_{RA}$", zorder=1000, fontsize=this_fontsize)

ax.set_xlim(-1.1, 1.1)
ax.set_ylim(-8.0, 8.0)
ax.xaxis.set_tick_params(labelsize=18, width=1)
ax.yaxis.set_tick_params(labelsize=18, width=1)
ax.yaxis.set_major_locator(plt.MaxNLocator(nbins=6))
ax.set_xlabel("$x_1$", fontsize=this_fontsize)
ax.set_ylabel("$x_2$", fontsize=this_fontsize)
plt.show()
# Out:
# /tmp/ipykernel_440286/994042884.py:68: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(
# /tmp/ipykernel_440286/994042884.py:77: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(

# %%
# ── Control input signals along MPC trajectories ─────────────────────────────
px_fig = 1 / plt.rcParams["figure.dpi"]
fig, ax = plt.subplots(figsize=(650 * px_fig, 150 * px_fig), layout="constrained")
fig.set_dpi(200)

for this_traj, this_u in zip(traj_x_mpc, traj_u_mpc):
    if len(this_u) == 0:
        continue
    t_vals = np.arange(len(this_u)) * dt
    ax.step(t_vals, this_u, lw=2, alpha=0.65, where="post")

ax.axhline(
    u_max, color="gray", lw=1.0, ls="--", alpha=0.6, label=f"bound \u00b1{u_max}"
)
ax.axhline(-u_max, color="gray", lw=1.0, ls="--", alpha=0.6)
ax.axhline(0, color="gray", lw=0.8, ls=":")

fs = 20
ax.set_xlabel("Time [s]", fontsize=fs - 4)
ax.set_ylabel("$u$", fontsize=fs - 4)
ax.xaxis.set_tick_params(labelsize=15)
ax.yaxis.set_tick_params(labelsize=15)
ax.set_xlim(0, None)
# ax.legend(fontsize=14, loc="upper right")
ax.grid(True, alpha=0.3)
plt.show()
